# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('temp/steam_pivoted.csv')
df2 = pd.read_csv('temp/user_steam_lib_w_na.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120407 entries, 0 to 120406
# Data columns (total 4 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   user_id   120407 non-null  int64
#  1   name      120407 non-null  object
#  2   play      120407 non-null  float64
#  3   purchase  120407 non-null  int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 3.7+ MB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120490 entries, 0 to 120489
# Data columns (total 22 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        120490 non-null  int64
#  1   user_id           120490 non-null  int64
#  2   name              120490 non-null  object
#  3   play              120490 non-null  float64
#  4   purchase          120490 non-null  int64
#  5   appid             84004 non-null   float64
#  6   release_date      84004 non-null   object
#  7   english           84004 non-null   float64
#  8   developer         84004 non-null   object
#  9   publisher         84004 non-null   object
#  10  platforms         84004 non-null   object
#  11  required_age      84004 non-null   float64
#  12  categories        84004 non-null   object
#  13  genres            84004 non-null   object
#  14  steamspy_tags     84004 non-null   object
#  15  achievements      84004 non-null   float64
# ...

# %%
df2.head()
# Out:
#    Unnamed: 0  user_id                 name   play  purchase     appid  \
# 0           0     5250           alienswarm    4.9         1     630.0
# 1           1     5250       citiesskylines  144.0         1  255710.0
# 2           2     5250        counterstrike    0.0         1      10.0
# 3           3     5250  counterstrikesource    0.0         1     240.0
# 4           4     5250          dayofdefeat    0.0         1      30.0
#
#   release_date  english            developer            publisher  ...  \
# 0   2010-07-19      1.0                Valve                Valve  ...
# 1   2015-03-10      1.0  Colossal Order Ltd.  Paradox Interactive  ...
# 2   2000-11-01      1.0                Valve                Valve  ...
# 3   2004-11-01      1.0                Valve                Valve  ...
# 4   2003-05-01      1.0                Valve                Valve  ...
#
#                                           categories               genres  \
# ...

# %%
df3 = df2.iloc[:,[1,2,3,4]]

# %%
df3.head()
# Out:
#    user_id                 name   play  purchase
# 0     5250           alienswarm    4.9         1
# 1     5250       citiesskylines  144.0         1
# 2     5250        counterstrike    0.0         1
# 3     5250  counterstrikesource    0.0         1
# 4     5250          dayofdefeat    0.0         1

# %%
df.head()
# Out:
#    user_id                   name   play  purchase
# 0     5250            Alien Swarm    4.9         1
# 1     5250        Cities Skylines  144.0         1
# 2     5250         Counter-Strike    0.0         1
# 3     5250  Counter-Strike Source    0.0         1
# 4     5250          Day of Defeat    0.0         1

# %%
# get rid of special char and whitespaces in the unique games df (user action repo)
df['name'] = df.name.replace('[^a-zA-Z0-9]+', '', regex=True)

# convert the names to lowercase
df['name'] = df['name'].str.lower()

df.head()
# Out:
#    user_id                 name   play  purchase
# 0     5250           alienswarm    4.9         1
# 1     5250       citiesskylines  144.0         1
# 2     5250        counterstrike    0.0         1
# 3     5250  counterstrikesource    0.0         1
# 4     5250          dayofdefeat    0.0         1

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120490 entries, 0 to 120489
# Data columns (total 4 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   user_id   120490 non-null  int64
#  1   name      120490 non-null  object
#  2   play      120490 non-null  float64
#  3   purchase  120490 non-null  int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 3.7+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120407 entries, 0 to 120406
# Data columns (total 4 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   user_id   120407 non-null  int64
#  1   name      120407 non-null  object
#  2   play      120407 non-null  float64
#  3   purchase  120407 non-null  int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 3.7+ MB

# %%
df3.to_csv('joined_list_dbg.csv')
df.to_csv('action_list_dbg.csv')
